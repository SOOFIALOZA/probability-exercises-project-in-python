# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO
# import numpy as np
# np.random.seed(0)
# dice1 = np.random.randint(1,7,1000)
# dice2 = np.random.randint(1,7,1000)

# sum_list = []
# for i in range (0, len(dice1)):
#     sum_list.append(dice1[i]+dice2[i])
# # print(sum_list)

# mayores_que_7 = []

# for i in sum_list:
#     if i >= 7:
#         mayores_que_7.append(i)

# numerodeveces = len(mayores_que_7)

# print(numerodeveces)

# probabilidad = (numerodeveces / 1000 ) * 100

# print(probabilidad)


import numpy as np
import random

def dice_trial():
    dice1 = random.randint(1,6)
    dice2 = random.randint(1,6)
    return dice1+dice2


def sim(n_experiments):
    casos_favorables = 0
    result = 0
    for i in range(n_experiments):
        result = dice_trial()
        if result > 7 or result % 2 == 0:
            casos_favorables += 1
    return casos_favorables/ n_experiments


print(sim(1000))
# Out:
# 0.692

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. All are the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)

# 1. Take 3 white and 2 red.

def sim1(n_experiments):
    favorable = 0
    for i in range(n_experiments):
        colors = []
        for i in range(5):
            colors.append(ball_box[np.random.randint(0, 59)])
        colors = np.array(colors)  # es necesario convertirlo en un numpy array para luego poder sumar los valores de abajo
        whiteballs = sum(colors=="White")
        redballs = sum(colors=="Red")
        greenballs = sum(colors=="Green")

        if (whiteballs == 3) and (redballs == 2):
            favorable += 1
    return favorable / n_experiments

print(f"the probability 1 is:", sim1(10000))


# 2. All are the same color.
def sim2(n_experiments):
    favorable = 0
    for i in range(n_experiments):
        colors = []
        for i in range(5):
            colors.append(ball_box[np.random.randint(0, 59)])
        colors = np.array(colors) 
        whiteballs = sum(colors=="White")
        redballs = sum(colors=="Red")
        greenballs = sum(colors=="Green")

        if (whiteballs == 4) or (redballs == 2) or (greenballs == 5):
            favorable += 1
    return favorable / n_experiments

print(f"the probability 2 is:", sim2(10000))





# def take_balls(n_simulations = 1000):
#     count_1 = 0
#     count_2 = 0

#     for i in range(n_simulations):
#         colors = []

#         # Take 5 balls from the box
#         for i in range(5):
#             colors.append(ball_box[np.random.randint(0, 59)]) # np.random.randint(0,59), genera un numero aleatorio de entre 0 y 59, 
#             # un total de 60 elementos, tengo que tener en cuenta el 0. Gnera el numero y lo añade a la lista colors
#         colors = np.array(colors) #Convertimos la lista colors en un array para trabajar mejor
#         #Sumamos las pelotas de cada color 
#         white_balls = sum(colors == "White")
#         red_balls = sum(colors == "Red")
#         green_balls = sum(colors == "Green")

#         # creamos condiciones 
#         if (white_balls == 3) and (red_balls == 2):
#             count_1 += 1   #si se cumple la condicion suma 1 a la variable count1
        
#         if (white_balls == 5) or (red_balls == 5) or (green_balls == 5):
#             count_2 += 1
    
#     return count_1 / n_simulations, count_2 / n_simulations

# probabilities = take_balls(1000)

# print(f"The probability of 3 white and 2 red is: {np.round(probabilities[0] * 100, 2)}%")
# print(f"The probability of all the same color is: {np.round(probabilities[1] * 100, 2)}%")
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# the probability 1 is: 0.004
# the probability 2 is: 0.3548
